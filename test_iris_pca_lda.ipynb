# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.decomposition import PCA, KernelPCA
from sklearn.lda import LDA
from sklearn.linear_model import LogisticRegression

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target
target_names = iris.target_names

# %%
n_c=2
pca = PCA(n_components=n_c)
X_r = pca.fit(X).transform(X)
lda = LDA(n_components=n_c)
X_r2 = lda.fit(X, y).transform(X)
kpca = KernelPCA(n_components=n_c,kernel="rbf", gamma=0.1)
X_kpca = kpca.fit(X).transform(X)


plt.figure()
for c, i, target_name in zip("rgb", [0, 1, 2], target_names):
    plt.scatter(X_kpca[y == i, 0], X_kpca[y == i, 1], c=c, label=target_name)
plt.legend()
plt.title('KPCA of IRIS dataset gamma=0.1')

kpca = KernelPCA(n_components=n_c,kernel="rbf", gamma=1)
X_kpca = kpca.fit(X).transform(X)

plt.figure()
for c, i, target_name in zip("rgb", [0, 1, 2], target_names):
    plt.scatter(X_kpca[y == i, 0], X_kpca[y == i, 1], c=c, label=target_name)
plt.legend()
plt.title('KPCA of IRIS dataset gamma=1')

plt.figure()
for c, i, target_name in zip("rgb", [0, 1, 2], target_names):
    plt.scatter(X_r[y == i, 0], X_r[y == i, 1], c=c, label=target_name)
plt.legend()
plt.title('PCA of IRIS dataset')

plt.figure()
for c, i, target_name in zip("rgb", [0, 1, 2], target_names):
    plt.scatter(X_r2[y == i, 0], X_r2[y == i, 1], c=c, label=target_name)
plt.legend()
plt.title('LDA of IRIS dataset')

plt.show()

# %%
n_c=1
pca = PCA(n_components=n_c)
X_r = pca.fit(X).transform(X)
lda = LDA(n_components=n_c)
X_r2 = lda.fit(X, y).transform(X)
kpca = KernelPCA(n_components=n_c,kernel="rbf", gamma=0.1)
X_kpca = kpca.fit(X).transform(X)


kpca = KernelPCA(n_components=n_c,kernel="rbf", gamma=1)
X_kpca = kpca.fit(X).transform(X)


for c, i, target_name in zip("rgb", [0, 1, 2], target_names):
    plt.scatter(X_kpca[y == i, 0], X_kpca[y == i, 0]+1, c=c, label=target_name)

for c, i, target_name in zip("cyg", [0, 1, 2], target_names):
    plt.scatter(X_r[y == i, 0], 3+X_r[y == i, 0], c=c, label=target_name)
for c, i, target_name in zip("krb", [0, 1, 2], target_names):
    plt.scatter(X_r2[y == i, 0], 5+X_r2[y == i, 0], c=c, label=target_name)

plt.show()
